# %% [markdown]
# # Create and Save Your Yelp API Key

# %%
import json
import pandas as pd
from yelpapi import YelpAPI
with open('/Users/chris/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
results = yelp_api.search_query(location='Baltimore, MD',
                                       term='Crab Cake')
print(type(results))
results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# # Using the Yelp API

# %%
pizza = yelp_api.search_query(location='Chicago, IL',
                                       term='pizza')
type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
pizza1 = pd.DataFrame(pizza['businesses'])
pizza1.head(3)
# Out:
#                        id                          alias  \
# 0  DXwSYgiXqIVNdO9dazel6w       pequods-pizzeria-chicago
# 1  8vFJH_paXsMocmEO_KAa3w  lou-malnatis-pizzeria-chicago
# 2  Bxd9Y2PsdvIOGIKFQh53RQ           giordanos-chicago-30
#
#                      name                                          image_url  \
# 0       Pequod's Pizzeria  https://s3-media1.fl.yelpcdn.com/bphoto/8QJUNb...
# 1  Lou Malnati's Pizzeria  https://s3-media3.fl.yelpcdn.com/bphoto/FXGmfo...
# 2              Giordano's  https://s3-media1.fl.yelpcdn.com/bphoto/OKxuR9...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/pequods-pizzeria-chic...          7192
# 1      False  https://www.yelp.com/biz/lou-malnatis-pizzeria...          6832
# 2      False  https://www.yelp.com/biz/giordanos-chicago-30?...          3304
#
#                                           categories  rating  \
# ...

# %%
pizza['total']
# Out:
# 5100

# %%
pizza_20 = yelp_api.search_query(location='Chicago, IL',
                                       term='pizza',
                               offset=20)

# %%
pizza20 = pd.DataFrame(pizza_20['businesses'])
pizza20.head(3)
# Out:
#                        id                                      alias  \
# 0  Rn3o8GcYBPFJX5MWJn0r1Q  roberts-pizza-and-dough-company-chicago-2
# 1  aEYu5fU5i2HKBOkvC9Zm7w                        ricobenes-chicago-4
# 2  lng1ZrsRzCE9bA2MlMQPHQ                         pizza-lobo-chicago
#
#                              name  \
# 0  Robert's Pizza & Dough Company
# 1                      Ricobene's
# 2                      Pizza Lobo
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/0KtoeK...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/1-au8M...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/utw98w...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/roberts-pizza-and-dou...           656
# 1  https://www.yelp.com/biz/ricobenes-chicago-4?a...          1027
# 2  https://www.yelp.com/biz/pizza-lobo-chicago?ad...           124
#
# ...

# %%
pizza_all = pd.concat([pizza1, pizza20],
                      ignore_index=True)
display(pizza_all.head(3), pizza_all.tail(3))
# Out:
#                        id                          alias  \
# 0  DXwSYgiXqIVNdO9dazel6w       pequods-pizzeria-chicago
# 1  8vFJH_paXsMocmEO_KAa3w  lou-malnatis-pizzeria-chicago
# 2  Bxd9Y2PsdvIOGIKFQh53RQ           giordanos-chicago-30
#
#                      name                                          image_url  \
# 0       Pequod's Pizzeria  https://s3-media1.fl.yelpcdn.com/bphoto/8QJUNb...
# 1  Lou Malnati's Pizzeria  https://s3-media3.fl.yelpcdn.com/bphoto/FXGmfo...
# 2              Giordano's  https://s3-media1.fl.yelpcdn.com/bphoto/OKxuR9...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/pequods-pizzeria-chic...          7192
# 1      False  https://www.yelp.com/biz/lou-malnatis-pizzeria...          6832
# 2      False  https://www.yelp.com/biz/giordanos-chicago-30?...          3304
#
#                                           categories  rating  \
# ...

# %%
pizza_all.to_json(orient='records')
# Out:
# '[{"id":"DXwSYgiXqIVNdO9dazel6w","alias":"pequods-pizzeria-chicago","name":"Pequod\'s Pizzeria","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/8QJUNblfCI0EDhOjuIWJ4A\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/pequods-pizzeria-chicago?adjust_creative=Il2GSoqWL1ItZo3P745WAw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Il2GSoqWL1ItZo3P745WAw","review_count":7192,"categories":[{"alias":"pizza","title":"Pizza"}],"rating":4.0,"coordinates":{"latitude":41.92187,"longitude":-87.664486},"transactions":["delivery","pickup"],"price":"$$","location":{"address1":"2207 N Clybourn Ave","address2":"","address3":"","city":"Chicago","zip_code":"60614","country":"US","state":"IL","display_address":["2207 N Clybourn Ave","Chicago, IL 60614"]},"phone":"+17733271512","display_phone":"(773) 327-1512","distance":2158.7084581522},{"id":"8vFJH_paXsMocmEO_KAa3w","alias":"lou-malnatis-pizzeria-chicago","name":"Lou Malnati\'s Pizzeria","image_url":"h
# ...
